# %%
class Model:
    field_1 = 123
    field_2 = "123"
    meta = {
        "atr_1": 1,
        "atr_2": 1,
    }

    class Meta:
        atr_1 = 1
        atr_2 = 1

class SpecialModel(Model):
    field_1 = 123
    field_2 = "123"
    meta = {
        "s_atr_1": 1,
        "s_atr_2": 1,
    }

#    class Meta():
#        s_atr_1 = 1
#        s_atr_2 = 1

    class Meta(Model.Meta):
        s_atr_1 = 1
        s_atr_2 = 1

# %%
SpecialModel.meta
# Out:
# {'s_atr_1': 1, 's_atr_2': 1}

# %%
def fun():
    print("fun")
    def inner_fun():
        print("inner_fun")

    inner_fun()

# %%
fun()
# Out:
# fun
# inner_fun

# %%
def inner_fun():
    print("inner_fun")

def fun():
    print("fun")

    inner_fun()

fun()
# Out:
# fun
# inner_fun

# %%
def fun(): return 1

# %%
fun
# Out:
# <function __main__.fun()>

# %%
id(fun)
# Out:
# 139934365455104

# %%
lambda a: a ** 2
# Out:
# <function __main__.<lambda>(a)>

# %%
lambda a: a ** 3
# Out:
# <function __main__.<lambda>(a)>

# %%
def is_number(value: str):
    if value.isdigit():
        return True
    return False

# %%
"1".isdigit
# Out:
# <function str.isdigit()>

# %%
l1 = ['1', 'q', '2', 't']
filter_obj = filter(is_number, l1)

# %%
for i in filter_obj:
    print(i)
# Out:
# 1
# 2

# %%
l1 = ['1', 'q', '2', 't']
filter_obj = filter(is_number, l1)
list(filter_obj)
# Out:
# ['1', '2']

# %%
l1 = ['1', 'q', '2', 't']
filter_obj = filter(lambda v: v.isdigit(), l1)
list(filter_obj)
# Out:
# ['1', '2']

# %%
l1 = ['1', 'q', '2', 't']
filter_obj = filter("any_valuy in (numbers)", l1)
list(filter_obj)

# %%
x = int(input(""))

# %%
# Одно и тоже
def is_number(value: str):
    if value.isdigit():
        return True
    return False

is_number("q")
# Out:
# False

# %%
is_number = lambda v: True if v.isdigit() else False
is_number("q")
# Out:
# False

# %%
is_number = True if "q".isdigit() else False
is_number
# Out:
# False

# %%
Model.Meta.atr_1
# Out:
# 1

# %%
SpecialModel.Meta
# Out:
# __main__.SpecialModel.Meta

# %%
# Наследование

# %%
# Полиморфизм - возможность обращаться к подструктурам (вложенностям) ожидаемым образом
class Human:
    def make_sound(self):
        print("Привет")

class Animal:
    def make_sound_animal(self):
        print("Woooow")

# %%
h1 = h2 = Human()
a1 = a2 = Animal()

# %%
l1 = [Human(), Human(),  Animal(), Animal()]
for obj in l1:
    obj.make_sound()
# Out:
# Привет
# Привет
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 3
#       1 l1 = [Human(), Human(),  Animal(), Animal()]
#       2 for obj in l1:
# ----> 3     obj.make_sound()
#
# AttributeError: 'Animal' object has no attribute 'make_sound'

# %%
# Абстрактный класс
# Интерфейсы
